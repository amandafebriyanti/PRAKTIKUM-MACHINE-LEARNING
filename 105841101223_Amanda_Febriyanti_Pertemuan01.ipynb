# %%
import numpy as np          # library komputasi angka & array
import pandas as pd          # library tabel data (DataFrame)
import matplotlib.pyplot as plt  # library grafik
from sklearn.datasets import load_iris  # dataset bawaan scikit-learn

# --- NumPy ---
# Membuat array angka lalu menghitung rata-rata.
x = np.array([1, 2, 3, 4, 5])
print("mean:", x.mean())

# --- Pandas ---
# Membuat tabel kecil berisi nama dan nilai, lalu menampilkannya.
df = pd.DataFrame({"nama": ["A", "B", "C"], "nilai": [80, 75, 90]})
print(df)

# --- Visualisasi ---
# Membuat bar chart dari tabel di atas.
df.plot(kind="bar", x="nama", y="nilai", legend=False)
plt.show()  # plt.show() wajib agar grafik muncul

# --- Dataset ML ---
# Memuat dataset Iris (150 bunga, 4 fitur, 3 kelas).
iris = load_iris(as_frame=True)  # as_frame=True agar langsung jadi DataFrame (opsional)
print(iris.frame.head())          # menampilkan 5 baris pertama
# Out:
# mean: 3.0
#   nama  nilai
# 0    A     80
# 1    B     75
# 2    C     90
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_wine

# Set seed agar angka random konsisten setiap dijalankan
np.random.seed(42)

print("--- Memulai Tugas Praktikum ---\n")

# 1. TUGAS NUMPY
+

# 2. TUGAS PANDAS

# Menampilkan 3 nilai tertinggi
top_3 = df_mhs.nlargest(3, 'Nilai')
print("\n2b. 3 Nilai Tertinggi:")
print(top_3.to_string(index=False))
print("\n")

# 3. TUGAS VISUALISASI
print("3. Menampilkan Grafik...")
# Ukuran diperkecil (10x5) agar tidak terlalu besar di layar
plt.figure(figsize=(10, 5))

# Grafik Batang (Subplot 1 dari 2 kolom)
plt.subplot(1, 2, 1)
plt.bar(df_mhs['Nama'], df_mhs['Nilai'], color='skyblue')
plt.title('Grafik Batang Nilai')
plt.xticks(rotation=45)

# Grafik Bulat / Pie Chart (Subplot 2 dari 2 kolom)
# Menggunakan 1, 2, 2 agar langsung berdampingan tanpa jarak kosong di tengah
plt.subplot(1, 2, 2)
plt.pie(df_mhs['Nilai'], labels=df_mhs['Nama'], autopct='%1.1f%%', startangle=140)
plt.title('Proporsi Nilai (Pie)')

# tight_layout otomatis mengatur spasi agar label tidak tumpang tindih
plt.tight_layout()
plt.show()

# 4. TUGAS DATASET (Scikit-Learn)
wine = load_wine(as_frame=True)
df_wine = wine.frame

print("\n4. Insight Dataset Wine:")
print(f"- Total Sampel: {df_wine.shape[0]}")
print(f"- Total Fitur: {df_wine.shape[1]}")
print(f"- Rata-rata Alkohol: {df_wine['alcohol'].mean():.2f}")
print("\n--- Selesai ---")
# Out:
# --- Memulai Tugas Praktikum ---
#
# 1. Hasil NumPy:
# Data: [51 92 14 71 60 20 82 86 74 74 87 99 23  2 21 52  1 87 29 37]
# Mean: 53.10
# Median: 56.0
# Std Dev: 31.47
#
# 2a. Semua Nilai Mahasiswa:
#     Nama  Nilai
#   Hizrah     85
# Hasriana     70
#    Manda     95
#    Yusuf     88
#    Rasma     60
#    Reski     75
#   Pahila     92
#   Andika     80
#    April     82
#    Indah     78
#
# 2b. 3 Nilai Tertinggi:
#   Nama  Nilai
#  Manda     95
# Pahila     92
#  Yusuf     88
#
#
# 3. Menampilkan Grafik...
# 4. Insight Dataset Wine:
# - Total Sampel: 178
# - Total Fitur: 14
# - Rata-rata Alkohol: 13.00
#
# --- Selesai ---
